# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# [2.12199579e-314 4.94065646e-324]

# %%
import itertools
marker = itertools.cycle((',', '+', '.', 'o', '*')) 
color = itertools.cycle(('lightskyblue', 'salmon', 'plum', 'yellow','lime', 'white')) 

def draw_bubbles(ax):
    for i in range(10):
        random_size = (np.random.rand(1)[0] * 15) + 5        
        y_plot = (np.random.rand(1)[0] * 2.5) + 4.5
        x_plot = (np.random.rand(1)[0] * 1) + 4.5
        ax.plot(x_plot, y_plot, marker= next(marker), color=next(color),  markersize=random_size)
        
    for i in range(15):
        random_size = (np.random.rand(1)[0] * 15) + 5        
        y_plot = (np.random.rand(1)[0] * 2) + 3.2
        x_plot = (np.random.rand(1)[0] * 2.5) + 3.8
        ax.plot(x_plot, y_plot, marker= next(marker), color=next(color), markersize=random_size)

# %%
fig, ax1 = plt.subplots(1,1, figsize=(10,10))

ax1.set_xlim(0,10)
ax1.set_ylim(0,10)
ax1.plot(5, 3, marker='s', color='brown', markersize=40)
ax1.plot(5, 7, marker='^', color='g', markersize=100)
ax1.plot(5, 6, marker='^', color='g', markersize=150)
ax1.plot(5, 5, marker='^', color='g', markersize=200)
ax1.plot(5, 8, marker='*', color='y', markersize=100)
ax1.plot(5, 8, marker='*', color='w', markersize=80)
ax1.plot(5, 8, marker='*', color='y', markersize=60)
ax1.plot(5, 8, marker='*', color='w', markersize=40)
ax1.plot(5, 8, marker='*', color='y', markersize=20)

draw_bubbles(ax1)
